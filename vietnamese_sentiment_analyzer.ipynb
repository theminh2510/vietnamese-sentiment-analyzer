# %% [markdown]
# <a href="https://colab.research.google.com/github/theminh2510/vietnamese-sentiment-analyzer/blob/main/vietnamese_sentiment_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello! AI World')
# Out:
# Hello! AI World
